# %% [markdown]
# # Phase 1: Extract plates

# %%
import os
import cv2
import xml.etree.ElementTree as ET
import numpy as np
from collections import defaultdict

# %%
# Folder paths
base_path = 'Plates2'
annotations_path = os.path.join(base_path, 'Vehicle Plates annotations', 'Vehicle Plates annotations')
images_path = os.path.join(base_path, 'Vehicle Plates 1280x1280', 'Vehicle Plates 1280x1280')
output_path = os.path.join('extracted_plates')

os.makedirs(output_path, exist_ok=True)

for xml_file in os.listdir(annotations_path):
    if not xml_file.endswith('.xml'):
        continue

    base_name = os.path.splitext(xml_file)[0]
    image_filename = f"{base_name}.png"
    image_path = os.path.join(images_path, image_filename)

    if not os.path.exists(image_path):
        print(f"❌ تصویر پیدا نشد: {image_path}")
        continue

    image = cv2.imread(image_path)
    if image is None:
        print(f"❌ خطا در بارگذاری تصویر: {image_filename}")
        continue

    # ابعاد واقعی تصویر
    h_img, w_img = image.shape[:2]

    # parse فایل XML
    xml_path = os.path.join(annotations_path, xml_file)
    tree = ET.parse(xml_path)
    root = tree.getroot()

    # ابعاد توی annotation (معمولاً 244x244)
    xml_width = int(root.find('size/width').text)
    xml_height = int(root.find('size/height').text)

    # محاسبه scale
    scale_x = w_img / xml_width
    scale_y = h_img / xml_height

    for obj in root.findall('object'):
        name = obj.find('name').text.strip().lower()
        if name != 'vehicle plate':
            continue

        bndbox = obj.find('bndbox')
        xmin = int(float(bndbox.find('xmin').text)) * scale_x
        ymin = int(float(bndbox.find('ymin').text)) * scale_y
        xmax = int(float(bndbox.find('xmax').text)) * scale_x
        ymax = int(float(bndbox.find('ymax').text)) * scale_y

        # تبدیل به int و محدود کردن داخل تصویر
        xmin, ymin = max(0, int(xmin)), max(0, int(ymin))
        xmax, ymax = min(w_img, int(xmax)), min(h_img, int(ymax))

        plate = image[ymin:ymax, xmin:xmax]

        plate_filename = f"{base_name}_plate.png"
        cv2.imwrite(os.path.join(output_path, plate_filename), plate)
        print(f"✅ ذخیره شد: {plate_filename}")
# Out:
# ✅ ذخیره شد: 1_plate.png
# ✅ ذخیره شد: 10_plate.png
# ✅ ذخیره شد: 100_plate.png
# ✅ ذخیره شد: 101_plate.png
# ✅ ذخیره شد: 102_plate.png
# ✅ ذخیره شد: 103_plate.png
# ✅ ذخیره شد: 104_plate.png
# ✅ ذخیره شد: 105_plate.png
# ✅ ذخیره شد: 106_plate.png
# ✅ ذخیره شد: 107_plate.png
# ✅ ذخیره شد: 108_plate.png
# ✅ ذخیره شد: 109_plate.png
# ✅ ذخیره شد: 11_plate.png
# ✅ ذخیره شد: 110_plate.png
# ✅ ذخیره شد: 111_plate.png
# ✅ ذخیره شد: 112_plate.png
# ✅ ذخیره شد: 113_plate.png
# ✅ ذخیره شد: 114_plate.png
# ✅ ذخیره شد: 115_plate.png
# ✅ ذخیره شد: 116_plate.png
# ✅ ذخیره شد: 117_plate.png
# ✅ ذخیره شد: 118_plate.png
# ✅ ذخیره شد: 119_plate.png
# ✅ ذخیره شد: 12_plate.png
# ✅ ذخیره شد: 120_plate.png
# ✅ ذخیره شد: 121_plate.png
# ✅ ذخیره شد: 122_plate.png
# ✅ ذخیره شد: 123_plate.png
# ✅ ذخیره شد: 124_plate.png
# ✅ ذخیره شد: 125_plate.png
# ✅ ذخیره شد: 126_plate.png
# ✅ ذخیره شد: 127_plate.png
# ✅ ذخیره شد: 128_plate.png
# ✅ ذخیره شد: 129_plate.png
# ✅ ذخیره شد: 13_plate.png
# ✅ ذخیره شد: 130_plate.png
# ✅ ذخیره شد: 131_plate.png
# ✅ ذخیره شد: 132_plate.png
# ✅ ذخیره شد: 133_plate.png
# ✅ ذخیره شد: 134_plate.png
# ✅ ذخیره شد: 135_plate.png
# ✅ ذخیره شد: 136_plate.png
# ✅ ذخیره شد: 137_plate.png
# ✅ ذخیره شد: 138_plate.png
# ✅ ذخیره شد: 139_plate.png
# ✅ ذخیره شد: 14_plate.png
# ✅ ذخیره شد: 140_plate.png
# ✅ ذخیره شد: 141_plate.png
# ✅ ذخیره شد: 142_plate.png
# ✅ ذخیره شد: 143_plate.png
# ✅ ذخیره شد: 144_plate.png
# ✅ ذخیره شد: 145_plate.png
# ✅ ذخیره شد: 146_plate.png
# ✅ ذخیره شد: 147_plate.png
# ✅ ذخیره شد: 148_plate.png
# ✅ ذخیره شد: 149_plate.png
# ✅ ذخیره شد: 15_plate.png
# ✅ ذخیره شد: 150_plate.png
# ✅ ذخیره شد: 151_plate.png
# ✅ ذخیره شد: 152_plate.png
# ✅ ذخیره شد: 153_plate.png
# ✅ ذخیره شد: 154_plate.png
# ✅ ذخیره شد: 155_plate.png
# ✅ ذخیره شد: 156_plate.png
# ✅ ذخیره شد: 157_plate.png
# ✅ ذخیره شد: 158_plate.png
# ✅ ذخیره شد: 159_plate.png
# ✅ ذخیره شد: 16_plate.png
# ✅ ذخیره شد: 160_plate.png
# ✅ ذخیره شد: 161_plate.png
# ✅ ذخیره شد: 162_plate.png
# ✅ ذخیره شد: 163_plate.png
# ✅ ذخیره شد: 164_plate.png
# ✅ ذخیره شد: 165_plate.png
# ✅ ذخیره شد: 166_plate.png
# ✅ ذخیره شد: 167_plate.png
# ✅ ذخیره شد: 168_plate.png
# ✅ ذخیره شد: 169_plate.png
# ✅ ذخیره شد: 17_plate.png
# ✅ ذخیره شد: 170_plate.png
# ✅ ذخیره شد: 171_plate.png
# ✅ ذخیره شد: 172_plate.png
# ✅ ذخیره شد: 173_plate.png
# ✅ ذخیره شد: 174_plate.png
# ✅ ذخیره شد: 175_plate.png
# ✅ ذخیره شد: 176_plate.png
# ✅ ذخیره شد: 177_plate.png
# ✅ ذخیره شد: 178_plate.png
# ✅ ذخیره شد: 179_plate.png
# ✅ ذخیره شد: 18_plate.png
# ✅ ذخیره شد: 180_plate.png
# ✅ ذخیره شد: 181_plate.png
# ✅ ذخیره شد: 182_plate.png
# ✅ ذخیره شد: 183_plate.png
# ✅ ذخیره شد: 184_plate.png
# ✅ ذخیره شد: 185_plate.png
# ✅ ذخیره شد: 186_plate.png
# ✅ ذخیره شد: 187_plate.png
# ✅ ذخیره شد: 188_plate.png
# ✅ ذخیره شد: 189_plate.png
# ✅ ذخیره شد: 19_plate.png
# ✅ ذخیره شد: 190_plate.png
# ✅ ذخیره شد: 191_plate.png
# ✅ ذخیره شد: 192_plate.png
# ✅ ذخیره شد: 193_plate.png
# ✅ ذخیره شد: 194_plate.png
# ✅ ذخیره شد: 195_plate.png
# ✅ ذخیره شد: 196_plate.png
# ✅ ذخیره شد: 197_plate.png
# ✅ ذخیره شد: 198_plate.png
# ✅ ذخیره شد: 199_plate.png
# ✅ ذخیره شد: 2_plate.png
# ✅ ذخیره شد: 20_plate.png
# ✅ ذخیره شد: 200_plate.png
# ✅ ذخیره شد: 201_plate.png
# ✅ ذخیره شد: 202_plate.png
# ✅ ذخیره شد: 203_plate.png
# ✅ ذخیره شد: 204_plate.png
# ✅ ذخیره شد: 205_plate.png
# ✅ ذخیره شد: 206_plate.png
# ✅ ذخیره شد: 207_plate.png
# ✅ ذخیره شد: 208_plate.png
# ✅ ذخیره شد: 209_plate.png
# ✅ ذخیره شد: 21_plate.png
# ✅ ذخیره شد: 210_plate.png
# ✅ ذخیره شد: 211_plate.png
# ✅ ذخیره شد: 212_plate.png
# ✅ ذخیره شد: 213_plate.png
# ✅ ذخیره شد: 214_plate.png
# ✅ ذخیره شد: 215_plate.png
# ✅ ذخیره شد: 216_plate.png
# ✅ ذخیره شد: 217_plate.png
# ✅ ذخیره شد: 22_plate.png
# ✅ ذخیره شد: 23_plate.png
# ✅ ذخیره شد: 24_plate.png
# ✅ ذخیره شد: 25_plate.png
# ✅ ذخیره شد: 26_plate.png
# ✅ ذخیره شد: 27_plate.png
# ✅ ذخیره شد: 28_plate.png
# ✅ ذخیره شد: 29_plate.png
# ✅ ذخیره شد: 3_plate.png
# ✅ ذخیره شد: 30_plate.png
# ✅ ذخیره شد: 31_plate.png
# ✅ ذخیره شد: 32_plate.png
# ✅ ذخیره شد: 33_plate.png
# ✅ ذخیره شد: 34_plate.png
# ✅ ذخیره شد: 35_plate.png
# ✅ ذخیره شد: 36_plate.png
# ✅ ذخیره شد: 37_plate.png
# ✅ ذخیره شد: 38_plate.png
# ✅ ذخیره شد: 39_plate.png
# ✅ ذخیره شد: 4_plate.png
# ✅ ذخیره شد: 40_plate.png
# ✅ ذخیره شد: 41_plate.png
# ✅ ذخیره شد: 42_plate.png
# ✅ ذخیره شد: 43_plate.png
# ✅ ذخیره شد: 44_plate.png
# ✅ ذخیره شد: 45_plate.png
# ✅ ذخیره شد: 46_plate.png
# ✅ ذخیره شد: 47_plate.png
# ✅ ذخیره شد: 48_plate.png
# ✅ ذخیره شد: 49_plate.png
# ✅ ذخیره شد: 5_plate.png
# ✅ ذخیره شد: 50_plate.png
# ✅ ذخیره شد: 51_plate.png
# ✅ ذخیره شد: 52_plate.png
# ✅ ذخیره شد: 53_plate.png
# ✅ ذخیره شد: 54_plate.png
# ✅ ذخیره شد: 55_plate.png
# ✅ ذخیره شد: 56_plate.png
# ✅ ذخیره شد: 57_plate.png
# ✅ ذخیره شد: 58_plate.png
# ✅ ذخیره شد: 59_plate.png
# ✅ ذخیره شد: 6_plate.png
# ✅ ذخیره شد: 60_plate.png
# ✅ ذخیره شد: 61_plate.png
# ✅ ذخیره شد: 62_plate.png
# ✅ ذخیره شد: 63_plate.png
# ✅ ذخیره شد: 64_plate.png
# ✅ ذخیره شد: 65_plate.png
# ✅ ذخیره شد: 66_plate.png
# ✅ ذخیره شد: 67_plate.png
# ✅ ذخیره شد: 68_plate.png
# ✅ ذخیره شد: 69_plate.png
# ✅ ذخیره شد: 7_plate.png
# ✅ ذخیره شد: 70_plate.png
# ✅ ذخیره شد: 71_plate.png
# ✅ ذخیره شد: 72_plate.png
# ✅ ذخیره شد: 73_plate.png
# ✅ ذخیره شد: 74_plate.png
# ✅ ذخیره شد: 75_plate.png
# ✅ ذخیره شد: 76_plate.png
# ✅ ذخیره شد: 77_plate.png
# ✅ ذخیره شد: 78_plate.png
# ✅ ذخیره شد: 79_plate.png
# ✅ ذخیره شد: 8_plate.png
# ✅ ذخیره شد: 80_plate.png
# ✅ ذخیره شد: 81_plate.png
# ✅ ذخیره شد: 82_plate.png
# ✅ ذخیره شد: 83_plate.png
# ✅ ذخیره شد: 84_plate.png
# ✅ ذخیره شد: 85_plate.png
# ✅ ذخیره شد: 86_plate.png
# ✅ ذخیره شد: 87_plate.png
# ✅ ذخیره شد: 88_plate.png
# ✅ ذخیره شد: 89_plate.png
# ✅ ذخیره شد: 9_plate.png
# ✅ ذخیره شد: 90_plate.png
# ✅ ذخیره شد: 91_plate.png
# ✅ ذخیره شد: 92_plate.png
# ✅ ذخیره شد: 93_plate.png
# ✅ ذخیره شد: 94_plate.png
# ✅ ذخیره شد: 95_plate.png
# ✅ ذخیره شد: 96_plate.png
# ✅ ذخیره شد: 97_plate.png
# ✅ ذخیره شد: 98_plate.png
# ✅ ذخیره شد: 99_plate.png

# %% [markdown]
# # Phase 2: Extract alphabets

# %%
# مسیر پوشه‌های ورودی و خروجی
plates_dir = 'extracted_plates'

base_output_folder = "output"
deskew_gray_image_path = os.path.join(base_output_folder, "1-deskew_gray_image")
blurred_path = os.path.join(base_output_folder, "2-blurred")
thresh_path = os.path.join(base_output_folder, "3-thresh")
dilated_path = os.path.join(base_output_folder, "4-dilated")
dilated_output_dir = os.path.join(base_output_folder, "Extracted_characters_dilated")
thresh_output_dir = os.path.join(base_output_folder, "Extracted_characters_thresh")
full_composite_dir = os.path.join(base_output_folder, "full_composite")

# ایجاد پوشه‌ها
os.makedirs(base_output_folder, exist_ok=True)
os.makedirs(deskew_gray_image_path, exist_ok=True)
os.makedirs(blurred_path, exist_ok=True)
os.makedirs(thresh_path, exist_ok=True)
os.makedirs(dilated_path, exist_ok=True)
os.makedirs(dilated_output_dir, exist_ok=True)
os.makedirs(thresh_output_dir, exist_ok=True)
os.makedirs(full_composite_dir, exist_ok=True)


def deskew_image(img):
    """صاف کردن تصویر با Hough Line Detection"""
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150)
    lines = cv2.HoughLines(edges, 1, np.pi/180, 100)

    if lines is not None:
        angles = []
        for rho, theta in lines[:, 0]:
            angle = (theta - np.pi/2) * 180/np.pi
            if -45 < angle < 45:
                angles.append(angle)
        if angles:
            avg_angle = np.mean(angles)
            (h, w) = img.shape[:2]
            M = cv2.getRotationMatrix2D((w // 2, h // 2), avg_angle, 1.0)
            img = cv2.warpAffine(img, M, (w, h), flags=cv2.INTER_LINEAR)
    return img

def put_label(img, label):
    img = cv2.copyMakeBorder(img, 20, 0, 0, 0, cv2.BORDER_CONSTANT, value=255)
    cv2.putText(img, label, (5, 15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, 0, 1)
    return img

# ساخت تصویر ترکیبی کامل
def build_full_composite(plate_id, char_images):
    try:
        gray = cv2.imread(f"{deskew_gray_image_path}/{plate_id}_deskew_gray.png", cv2.IMREAD_GRAYSCALE)
        blurred = cv2.imread(f"{blurred_path}/{plate_id}_blurred.png", cv2.IMREAD_GRAYSCALE)
        thresh = cv2.imread(f"{thresh_path}/{plate_id}_thresh.png", cv2.IMREAD_GRAYSCALE)
        dilated = cv2.imread(f"{dilated_path}/{plate_id}_dilated.png", cv2.IMREAD_GRAYSCALE)

        steps = [gray, blurred, thresh, dilated]
        step_labels = ["gray", "blurred", "thresh", "dilated"]
        steps_labeled = [put_label(cv2.resize(img, (100, 100)), lbl) for img, lbl in zip(steps, step_labels)]
        row1 = cv2.hconcat(steps_labeled)

        chars_labeled = []
        for i, char in enumerate(char_images):
            char = cv2.resize(char, (28, 28))
            char_labeled = put_label(char, f"{i+1}")
            chars_labeled.append(char_labeled)

        while len(chars_labeled) < 8:
            empty = put_label(255 * np.ones((28, 28), dtype=np.uint8), "")
            chars_labeled.append(empty)

        row2 = cv2.hconcat(chars_labeled)
        row2_resized = cv2.resize(row2, (row1.shape[1], row1.shape[0]))
        full = cv2.vconcat([row1, row2_resized])

        save_path = f"{full_composite_dir}/{plate_id}_full.png"
        cv2.imwrite(save_path, full)
        print(f"🖼 تصویر کامل ذخیره شد: {save_path}")

    except Exception as e:
        print(f"⚠️ خطا در ساخت تصویر کامل {plate_id}: {e}")

# تابع استخراج و ذخیره کاراکترها + ساخت ترکیب
def func(num_labels, stats, thresh, output_dir, plate_id):
    components = []
    for i in range(1, num_labels):
        x, y, w, h, area = stats[i]
        if 80 < area < 6000 and h > 13 and w > 4:
            components.append((x, y, w, h, area))

    if len(components) == 0:
        print(f"⚠️ هیچ کاراکتری شناسایی نشد در {plate_id}")
        return

    components = sorted(components, key=lambda b: b[3], reverse=True)[:8]
    components = sorted(components, key=lambda b: b[0])

    char_images = []

    for idx, (x, y, w, h, _) in enumerate(components):
        char_img = thresh[y:y+h, x:x+w]

        # معکوس کردن رنگ (کاراکتر مشکی روی سفید)
        char_img = 255 - char_img

        # کوچک‌سازی کاراکتر به ابعاد کوچکتر (مثلاً 100x100)
        resized_char = cv2.resize(char_img, (23, 23))

        # ساخت بوم سفید
        canvas = 255 * np.ones((28, 28), dtype=np.uint8)

        # محاسبه مکان شروع برای قرارگیری وسط
        start_y = (28 - 23) // 2
        start_x = (28 - 23) // 2

        # قرار دادن تصویر کوچک‌شده در مرکز
        canvas[start_y:start_y+23, start_x:start_x+23] = resized_char

        save_path = os.path.join(output_dir, f"{plate_id}_char_{idx+1}.png")
        cv2.imwrite(save_path, canvas)
        char_images.append(canvas)
        print(f"✅ ذخیره شد: {save_path}")

    # ساخت تصویر نهایی
    build_full_composite(plate_id, char_images)
    

def extract_characters_from_plate(image_path, plate_id):
    img = cv2.imread(image_path)
    if img is None:
        print(f"❌ تصویر یافت نشد: {image_path}")
        return
    
    img = deskew_image(img)

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (5, 5), 0) # using 5*5 filter instead of 3*3 
    _, thresh = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # عملیات مورفولوژیک قوی‌تر
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=2)
    dilated = cv2.dilate(morph, kernel, iterations=2)  # افزایش iterations 
        
    # show_image(dilated)
    cv2.imwrite(os.path.join(deskew_gray_image_path, f"{plate_id}_deskew_gray.png"), gray)
    cv2.imwrite(os.path.join(blurred_path, f"{plate_id}_blurred.png"), blurred)
    cv2.imwrite(os.path.join(thresh_path, f"{plate_id}_thresh.png"), thresh)
    cv2.imwrite(os.path.join(dilated_path, f"{plate_id}_dilated.png"), dilated)

    # connected components
    num_labels_dilated, labels_dilated, stats_dilated, centroids_dilated = cv2.connectedComponentsWithStats(dilated, connectivity=8)
    num_labels_thresh, labels_thresh, stats_thresh, centroids_thresh = cv2.connectedComponentsWithStats(thresh, connectivity=8)

    func(num_labels_dilated, stats_dilated, thresh, dilated_output_dir,plate_id)
    func(num_labels_thresh, stats_thresh, thresh, thresh_output_dir,plate_id)

# اجرای پردازش روی تمام پلاک‌ها
for fname in os.listdir(plates_dir):
    if fname.endswith('.png'):
        plate_path = os.path.join(plates_dir, fname)
        plate_id = os.path.splitext(fname)[0]
        extract_characters_from_plate(plate_path, plate_id)
# Out:
# ✅ ذخیره شد: output\Extracted_characters_dilated\100_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\100_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\100_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\100_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\100_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\100_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\100_plate_char_7.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/100_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\100_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\100_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\100_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\100_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\100_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\100_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\100_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\100_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/100_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\101_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\101_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\101_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\101_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\101_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\101_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\101_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\101_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/101_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\101_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\101_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\101_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\101_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\101_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\101_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\101_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\101_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/101_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\102_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\102_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\102_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\102_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\102_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\102_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\102_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\102_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/102_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\102_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\102_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\102_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\102_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\102_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\102_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\102_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\102_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/102_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\103_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\103_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\103_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\103_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\103_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\103_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\103_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\103_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/103_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\103_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\103_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\103_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\103_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\103_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\103_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\103_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\103_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/103_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\104_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\104_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\104_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\104_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\104_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\104_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\104_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\104_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/104_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\104_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\104_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\104_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\104_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\104_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\104_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\104_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\104_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/104_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\105_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\105_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\105_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\105_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\105_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\105_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\105_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\105_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/105_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\105_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\105_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\105_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\105_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\105_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\105_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\105_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\105_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/105_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\106_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\106_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\106_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\106_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\106_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\106_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\106_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\106_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/106_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\106_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\106_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\106_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\106_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh
plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\95_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\95_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\95_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\95_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\95_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\95_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/95_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\96_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\96_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\96_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\96_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\96_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\96_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\96_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\96_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/96_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\96_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\96_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\96_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\96_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\96_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\96_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\96_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\96_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/96_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\97_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\97_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\97_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\97_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\97_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\97_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\97_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\97_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/97_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\97_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\97_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\97_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\97_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\97_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\97_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\97_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\97_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/97_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\98_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\98_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\98_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\98_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\98_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\98_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\98_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\98_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/98_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\98_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\98_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\98_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\98_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\98_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\98_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\98_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\98_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/98_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\99_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\99_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\99_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\99_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\99_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\99_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\99_plate_char_7.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/99_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\99_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\99_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\99_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\99_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\99_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\99_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\99_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\99_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/99_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\9_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\9_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\9_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\9_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\9_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\9_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\9_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_dilated\9_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/9_plate_full.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\9_plate_char_1.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\9_plate_char_2.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\9_plate_char_3.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\9_plate_char_4.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\9_plate_char_5.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\9_plate_char_6.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\9_plate_char_7.png
# ✅ ذخیره شد: output\Extracted_characters_thresh\9_plate_char_8.png
# 🖼 تصویر کامل ذخیره شد: output\full_composite/9_plate_full.png

# %% [markdown]
# # Phase 3: Train models

# %%
from PIL import Image
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from skimage.feature import hog
import fnmatch
import shutil
import random
from scipy.ndimage import gaussian_filter, map_coordinates

# %% [markdown]
# ##### preprocess train data (crop the paddings(white spaces)) and extract the characters

# %%
def crop_character(img_array):
    """
    Crop the character from the image by removing white borders.
    No padding is added.
    """
    inverted = 255 - img_array
    coords = cv2.findNonZero(inverted)
    if coords is None:
        return img_array
    x, y, w, h = cv2.boundingRect(coords)
    cropped = img_array[y : y + h, x : x + w]
    return cropped

input_root = "alpha"  # root input folder
output_root = "alpha_cropped"  # output folder with same structure
target_size = (28, 28)  # resize target
os.makedirs(output_root, exist_ok=True)

for root, dirs, files in os.walk(input_root):
    for file in files:
        if file.lower().endswith((".png", ".jpg", ".jpeg")):
            input_path = os.path.join(root, file)
            relative_path = os.path.relpath(root, input_root)
            output_dir = os.path.join(output_root, relative_path)
            os.makedirs(output_dir, exist_ok=True)

            try:
                img = Image.open(input_path).convert("L")
                img_array = np.array(img)

                # Crop character and resize to 50x50
                cropped = crop_character(img_array)
                resized = cv2.resize(cropped, target_size, interpolation=cv2.INTER_AREA)

                # Save the result
                save_path = os.path.join(output_dir, file)
                cv2.imwrite(save_path, resized)
                print(f"✅ Saved: {save_path}")
            except Exception as e:
                print(f"❌ Error processing {input_path}: {e}")
# Out:
# ✅ Saved: alpha_cropped\10-d\100d.jpg
# ✅ Saved: alpha_cropped\10-d\10d.jpg
# ✅ Saved: alpha_cropped\10-d\11d.jpg
# ✅ Saved: alpha_cropped\10-d\12d.jpg
# ✅ Saved: alpha_cropped\10-d\13d.jpg
# ✅ Saved: alpha_cropped\10-d\14d.jpg
# ✅ Saved: alpha_cropped\10-d\15d.jpg
# ✅ Saved: alpha_cropped\10-d\16d.jpg
# ✅ Saved: alpha_cropped\10-d\17d.jpg
# ✅ Saved: alpha_cropped\10-d\18d.jpg
# ✅ Saved: alpha_cropped\10-d\19d.jpg
# ✅ Saved: alpha_cropped\10-d\1d.jpg
# ✅ Saved: alpha_cropped\12-r\30r.jpg
# ✅ Saved: alpha_cropped\12-r\31r.jpg
# ✅ Saved: alpha_cropped\12-r\32r.jpg
# ✅ Saved: alpha_cropped\12-r\33r.jpg
# ✅ Saved: alpha_cropped\12-r\34r.jpg
# ✅ Saved: alpha_cropped\12-r\35r.jpg
# ✅ Saved: alpha_cropped\12-r\36r.jpg
# ✅ Saved: alpha_cropped\12-r\37r.jpg
# ✅ Saved: alpha_cropped\12-r\38r.jpg
# ✅ Saved: alpha_cropped\12-r\39r.jpg
# ✅ Saved: alpha_cropped\12-r\3r.jpg
# ✅ Saved: alpha_cropped\12-r\40r.jpg
# ✅ Saved: alpha_cropped\12-r\41r.jpg
# ✅ Saved: alpha_cropped\12-r\42r.jpg
# ✅ Saved: alpha_cropped\12-r\43r.jpg
# ✅ Saved: alpha_cropped\12-r\44r.jpg
# ✅ Saved: alpha_cropped\12-r\45r.jpg
# ✅ Saved: alpha_cropped\12-r\46r.jpg
# ✅ Saved: alpha_cropped\12-r\47r.jpg
# ✅ Saved: alpha_cropped\12-r\48r.jpg
# ✅ Saved: alpha_cropped\12-r\49r.jpg
# ✅ Saved: alpha_cropped\12-r\4r.jpg
# ✅ Saved: alpha_cropped\12-r\50r.jpg
# ✅ Saved: alpha_cropped\12-r\51r.jpg
# ✅ Saved: alpha_cropped\12-r\52r.jpg
# ✅ Saved: alpha_cropped\12-r\53r.jpg
# ✅ Saved: alpha_cropped\12-r\54r.jpg
# ✅ Saved: alpha_cropped\12-r\55r.jpg
# ✅ Saved: alpha_cropped\12-r\56r.jpg
# ✅ Saved: alpha_cropped\12-r\57r.jpg
# ✅ Saved: alpha_cropped\12-r\58r.jpg
# ✅ Saved: alpha_cropped\12-r\59r.jpg
# ✅ Saved: alpha_cropped\12-r\5r.jpg
# ✅ Saved: alpha_cropped\12-r\60r.jpg
# ✅ Saved: alpha_cropped\12-r\61r.jpg
# ✅ Saved: alpha_cropped\12-r\62r.jpg
# ✅ Saved: alpha_cropped\12-r\63r.jpg
# ✅ Saved: alpha_cropped\12-r\64r.jpg
# ✅ Saved: alpha_cropped\12-r\65r.jpg
# ✅ Saved: alpha_cropped\12-r\66r.jpg
# ✅ Saved: alpha_cropped\12-r\67r.jpg
# ✅ Saved: alpha_cropped\12-r\68r.jpg
# ✅ Saved: alpha_cropped\12-r\69r.jpg
# ✅ Saved: alpha_cropped\12-r\6r.jpg
# ✅ Saved: alpha_cropped\12-r\70.r.jpg
# ✅ Saved: alpha_cropped\12-r\71r.jpg
# ✅ Saved: alpha_cropped\12-r\72r.jpg
# ✅ Saved: alpha_cropped\12-r\73r.jpg
# ✅ Saved: alpha_cropped\12-r\74r.jpg
# ✅ Saved: alpha_cropped\12-r\75r.jpg
# ✅ Saved: alpha_cropped\12-r\76r.jpg
# ✅ Saved: alpha_cropped\12-r\77r.jpg
# ✅ Saved: alpha_cropped\12-r\78r.jpg
# ✅ Saved: alpha_cropped\12-r\79r.jpg
# ✅ Saved: alpha_cropped\12-r\7r.jpg
# ✅ Saved: alpha_cropped\12-r\80r.jpg
# ✅ Saved: alpha_cropped\12-r\81r.jpg
# ✅ Saved: alpha_cropped\12-r\82r.jpg
# ✅ Saved: alpha_cropped\12-r\83r.jpg
# ✅ Saved: alpha_cropped\12-r\84r.jpg
# ✅ Saved: alpha_cropped\12-r\85r.jpg
# ✅ Saved: alpha_cropped\12-r\86r.jpg
# ✅ Saved: alpha_cropped\12-r\87r.jpg
# ✅ Saved: alpha_cropped\12-r\88r.jpg
# ✅ Saved: alpha_cropped\12-r\89r.jpg
# ✅ Saved: alpha_cropped\12-r\8r.jpg
# ✅ Saved: alpha_cropped\12-r\90r.jpg
# ✅ Saved: alpha_cropped\12-r\91r.jpg
# ✅ Saved: alpha_cropped\12-r\92r.jpg
# ✅ Saved: alpha_cropped\12-r\93r.jpg
# ✅ Saved: alpha_cropped\12-r\94r.jpg
# ✅ Saved: alpha_cropped\12-r\95r.jpg
# ✅ Saved: alpha_cropped\12-r\96r.jpg
# ✅ Saved: alpha_cropped\12-r\97r.jpg
# ✅ Saved: alpha_cropped\12-r\98r.jpg
# ✅ Saved: alpha_cropped\12-r\99r.jpg
# ✅ Saved: alpha_cropped\12-r\9r.jpg
# ✅ Saved: alpha_cropped\13-z\100z.jpg
# ✅ Saved: alpha_cropped\13-z\10z.jpg
# ✅ Saved: alpha_cropped\13-z\11z.jpg
# ✅ Saved: alpha_cropped\13-z\12z.jpg
# ✅ Saved: alpha_cropped\13-z\13z.jpg
# ✅ Saved: alpha_cropped\13-z\14z.jpg
# ✅ Saved: alpha_cropped\13-z\15z.jpg
# ✅ Saved: alpha_cropped\13-z\16z.jpg
# ✅ Saved: alpha_cropped\13-z\17z.jpg
# ✅ Saved: alpha_cropped\13-z\18z.jpg
# ✅ Saved: alpha_cropped\13-z\19z.jpg
# ✅ Saved: alpha_cropped\13-z\1z.jpg
# ✅ Saved: alpha_cropped\13-z\20z.jpg
# ✅ Saved: alpha_cropped\13-z\21z.jpg
# ✅ Saved: alpha_cropped\13-z\22z.jpg
# ✅ Saved: alpha_cropped\13-z\23z.jpg
# ✅ Saved: alpha_cropped\13-z\24z.jpg
# ✅ Saved: alpha_cropped\13-z\25z.jpg
# ✅ Saved: alpha_cropped\13-z\26z.jpg
# ✅ Saved: alpha_cropped\13-z\27z.jpg
# ✅ Saved: alpha_cropped\13-z\28z.jpg
# ✅ Saved: alpha_cropped\13-z\29z.jpg
# ✅ Saved: alpha_cropped\13-z\2z.jpg
# ✅ Saved: alpha_cropped\13-z\30z.jpg
# ✅ Saved: alpha_cropped\13-z\31z.jpg
# ✅ Saved: alpha_cropped\13-z\32z.jpg
# ✅ Saved: alpha_cropped\13-z\33z.jpg
# ✅ Saved: alpha_cropped\13-z\34z.jpg
# ✅ Saved: alpha_cropped\13-z\35z.jpg
# ✅ Saved: alpha_cropped\13-z\36z.jpg
# ✅ Saved: alpha_cropped\13-z\37z.jpg
# ✅ Saved: alpha_cropped\13-z\38z.jpg
# ✅ Saved: alpha_cropped\13-z\39z.jpg
# ✅ Saved: alpha_cropped\13-z\3z.jpg
# ✅ Saved: alpha_cropped\13-z\40z.jpg
# ✅ Saved: alpha_cropped\13-z\41z.jpg
# ✅ Saved: alpha_cropped\13-z\42z.jpg
# ✅ Saved: alpha_cropped\13-z\43z.jpg
# ✅ Saved: alpha_cropped\13-z\44z.jpg
# ✅ Saved: alpha_cropped\13-z\45z.jpg
# ✅ Saved: alpha_cropped\13-z\46z.jpg
# ✅ Saved: alpha_cropped\13-z\47z.jpg
# ✅ Saved: alpha_cropped\13-z\48z.jpg
# ✅ Saved: alpha_cropped\13-z\49z.jpg
# ✅ Saved: alpha_cropped\13-z\4z.jpg
# ✅ Saved: alpha_cropped\13-z\50z.jpg
# ✅ Saved: alpha_cropped\13-z\51z.jpg
# ✅ Saved: alpha_cropped\13-z\52z.jpg
# ✅ Saved: alpha_cropped\13-z\53z.jpg
# ✅ Saved: alpha_cropped\13-z\54z.jpg
# ✅ Saved: alpha_cropped\13-z\55z.jpg
# ✅ Saved: alpha_cropped\13-z\56z.jpg
# ✅ Saved: alpha_cropped\13-z\57z.jpg
# ✅ Saved: alpha_cropped\13-z\58z.jpg
# ✅ Saved: alpha_cropped\13-z\59z.jpg
# ✅ Saved: alpha_cropped\13-z\5z.jpg
# ✅ Saved: alpha_cropped\13-z\60z.jpg
# ✅ Saved: alpha_cropped\13-z\61z.jpg
# ✅ Saved: alpha_cropped\13-z\62z.jpg
# ✅ Saved: alpha_cropped\13-z\63z.jpg
# ✅ Saved: alpha_cropped\13-z\64z.jpg
# ✅ Saved: alpha_cropped\13-z\65z.jpg
# ✅ Saved: alpha_cropped\13-z\66z.jpg
# ✅ Saved: alpha_cropped\13-z\67z.jpg
# ✅ Saved: alpha_cropped\13-z\68z.jpg
# ✅ Saved: alpha_cropped\13-z\69z.jpg
# ✅ Saved: alpha_cropped\13-z\6z.jpg
# ✅ Saved: alpha_cropped\13-z\70z.jpg
# ✅ Saved: alpha_cropped\13-z\71z.jpg
# ✅ Saved: alpha_cropped\13-z\72z.jpg
# ✅ Saved: alpha_cropped\13-z\73z.jpg
# ✅ Saved: alpha_cropped\13-z\74z.jpg
# ✅ Saved: alpha_cropped\13-z\75z.jpg
# ✅ Saved: alpha_cropped\13-z\76z.jpg
# ✅ Saved: alpha_cropped\13-z\77z.jpg
# ✅ Saved: alpha_cropped\13-z\78z.jpg
# ✅ Saved: alpha_cropped\13-z\79z.jpg
# ✅ Saved: alpha_cropped\13-z\7z.jpg
# ✅ Saved: alpha_cropped\13-z\80z.jpg
# ✅ Saved: alpha_cropped\13-z\81z.jpg
# ✅ Saved: alpha_cropped\13-z\82z.jpg
# ✅ Saved: alpha_cropped\13-z\83z.jpg
# ✅ Saved: alpha_cropped\13-z\84z.jpg
# ✅ Saved: alpha_cropped\13-z\85z.jpg
# ✅ Saved: alpha_cropped\13-z\86z.jpg
# ✅ Saved: alpha_cropped\13-z\87z.jpg
# ✅ Saved: alpha_cropped\13-z\88z.jpg
# ✅ Saved: alpha_cropped\13-z\89z.jpg
# ✅ Saved: alpha_cropped\13-z\8z.jpg
# ✅ Saved: alpha_cropped\13-z\90z.jpg
# ✅ Saved: alpha_cropped\13-z\91z.jpg
# ✅ Saved: alpha_cropped\13-z\92z.jpg
# ✅ Saved: alpha_cropped\13-z\93z.jpg
# ✅ Saved: alpha_cropped\13-z\94z.jpg
# ✅ Saved: alpha_cropped\13-z\95z.jpg
# ✅ Saved: alpha_cropped\13-z\96z.jpg
# ✅ Saved: alpha_cropped\13-z\97z.jpg
# ✅ Saved: alpha_cropped\13-z\98z.jpg
# ✅ Saved: alpha_cropped\13-z\99z.jpg
# ✅ Saved: alpha_cropped\13-z\9z.jpg
# ✅ Saved: alpha_cropped\14-zh\100zh.jpg
# ✅ Saved: alpha_cropped\14-zh\10zh.jpg
# ✅ Saved: alpha_cropped\14-zh\11zh.jpg
# ✅ Saved: alpha_cropped\14-zh\12zh.jpg
# ✅ Saved: alpha_cropped\14-zh\13zh.jpg
# ✅ Saved: alpha_cropped\14-zh\14zh.jpg
# ✅ Saved: alpha_cropped\14-zh\15zh.jpg
# ✅ Saved: alpha_cropped\14-zh\16zh.jpg
# ✅ Saved: alpha_cropped\14-zh\17zh.jpg
# ✅ Saved: alpha_cropped\14-zh\18zh.jpg
# ✅ Saved: alpha_cropped\14-zh\19zh.jpg
# ✅ Saved: alpha_cropped\14-zh\1zh.jpg
# ✅ Saved: alpha_cropped\14-zh\20zh.jpg
# ✅ Saved: alpha_cropped\14-zh\21zh.jpg
# ✅ Saved: alpha_cropped\14-zh\22zh.jpg
# ✅ Saved: alpha_cropped\14-zh\23zh.jpg
# ✅ Saved: alpha_cropped\14-zh\24zh.jpg
# ✅ Saved: alpha_cropped\14-zh\25zh.jpg
# ✅ Saved: alpha_cropped\14-zh\26zh.jpg
# ✅ Saved: alpha_cropped\14-zh\27zh.jpg
# ✅ Saved: alpha_cropped\14-zh\28zh.jpg
# ✅ Saved: alpha_cropped\14-zh\29zh.jpg
# ✅ Saved: alpha_cropped\14-zh\2zh.jpg
# ✅ Saved: alpha_cropped\14-zh\30zh.jpg
# ✅ Saved: alpha_cropped\14-zh\31zh.jpg
# ✅ Saved: alpha_cropped\14-zh\32zh.jpg
# ✅ Saved: alpha_cropped\14-zh\33zh.jpg
# ✅ Saved: alpha_cropped\14-zh\34zh.jpg
# ✅ Saved: alpha_cropped\14-zh\35zh.jpg
# ✅ Saved: alpha_cropped\14-zh\36zh.jpg
# ✅ Saved: alpha_cropped\14-zh\37zh.jpg
# ✅ Saved: alpha_cropped\14-zh\38zh.jpg
# ✅ Saved: alpha_cropped\14-zh\39zh.jpg
# ✅ Saved: alpha_cropped\14-zh\3zh.jpg
# ✅ Saved: alpha_cropped\14-zh\40zh.jpg
# ✅ Saved: alpha_cropped\14-zh\41zh.jpg
# ✅ Saved: alpha_cropped\14-zh\42zh.jpg
# ✅ Saved: alpha_cropped\14-zh\43zh.jpg
# ✅ Saved: alpha_cropped\14-zh\44zh.jpg
# ✅ Saved: alpha_cropped\14-zh\45zh.jpg
# ✅ Saved: alpha_cropped\14-zh\46zh.jpg
# ✅ Saved: alpha_cropped\14-zh\47zh.jpg
# ✅ Saved: alpha_cropped\14-zh\48zh.jpg
# ✅ Saved: alpha_cropped\14-zh\49zh.jpg
# ✅ Saved: alpha_cropped\14-zh\4zh.jpg
# ✅ Saved: alpha_cropped\14-zh\50zh.jpg
# ✅ Saved: alpha_cropped\14-zh\51zh.jpg
# ✅ Saved: alpha_cropped\14-zh\52zh.jpg
# ✅ Saved: alpha_cropped\14-zh\53zh.jpg
# ✅ Saved: alpha_cropped\14-zh\54zh.jpg
# ✅ Saved: alpha_cropped\14-zh\55zh.jpg
# ✅ Saved: alpha_cropped\14-zh\56zh.jpg
# ✅ Saved: alpha_cropped\14-zh\57zh.jpg
# ✅ Saved: alpha_cropped\14-zh\58zh.jpg
# ✅ Saved: alpha_cropped\14-zh\59zh.jpg
# ✅ Saved: alpha_cropped\14-zh\5zh.jpg
# ✅ Saved: alpha_cropped\14-zh\60zh.jpg
# ✅ Saved: alpha_cropped\14-zh\61zh.jpg
# ✅ Saved: alpha_cropped\14-zh\62zh.jpg
# ✅ Saved: alpha_cropped\14-zh\63zh.jpg
# ✅ Saved: alpha_cropped\14-zh\64zh.jpg
# ✅ Saved: alpha_cropped\14-zh\65zh.jpg
# ✅ Saved: alpha_cropped\14-zh\66zh.jpg
# ✅ Saved: alpha_cropped\14-zh\67zh.jpg
# ✅ Saved: alpha_cropped\14-zh\68zh.jpg
# ✅ Saved: alpha_cropped\14-zh\69zh.jpg
# ✅ Saved: alpha_cropped\14-zh\6zh.jpg
# ✅ Saved: alpha_cropped\14-zh\70zh.jpg
# ✅ Saved: alpha_cropped\14-zh\71zh.jpg
# ✅ Saved: alpha_cropped\14-zh\72zh.jpg
# ✅ Saved: alpha_cropped\14-zh\73zh.jpg
# ✅ Saved: alpha_cropped\14-zh\74zh.jpg
# ✅ Saved: alpha_cropped\14-zh\75zh.jpg
# ✅ Saved: alpha_cropped\14-zh\76zh.jpg
# ✅ Saved: alpha_cropped\14-zh\77zh.jpg
# ✅ Saved: alpha_cropped\14-zh\78zh.jpg
# ✅ Saved: alpha_cropped\14-zh\79zh.jpg
# ✅ Saved: alpha_cropped\14-zh\7zh.jpg
# ✅ Saved: alpha_cropped\14-zh\80zh.jpg
# ✅ Saved: alpha_cropped\14-zh\81zh.jpg
# ✅ Saved: alpha_cropped\14-zh\82zh.jpg
# ✅ Saved: alpha_cropped\14-zh\83zh.jpg
# ✅ Saved: alpha_cropped\14-zh\84zh.jpg
# ✅ Saved: alpha_cropped\14-zh\85zh.jpg
# ✅ Saved: alpha_cropped\14-zh\86zh.jpg
# ✅ Saved: alpha_cropped\14-zh\87zh.jpg
# ✅ Saved: alpha_cropped\14-zh\88zh.jpg
# ✅ Saved: alpha_cropped\14-zh\89zh.jpg
# ✅ Saved: alpha_cropped\14-zh\8zh.jpg
# ✅ Saved: alpha_cropped\14-zh\90zh.jpg
# ✅ Saved: alpha_cropped\14-zh\91zh.jpg
# ✅ Saved: alpha_cropped\14-zh\92zh.jpg
# ✅ Saved: alpha_cropped\14-zh\93zh.jpg
# ✅ Saved: alpha_cropped\14-zh\94zh.jpg
# ✅ Saved: alpha_cropped\14-zh\95zh.jpg
# ✅ Saved: alpha_cropped\14-zh\96zh.jpg
# ✅ Saved: alpha_cropped\14-zh\97zh.jpg
# ✅ Saved: alpha_cropped\14-zh\98zh.jpg
# ✅ Saved: alpha_cropped\14-zh\99zh.jpg
# ✅ Saved: alpha_cropped\14-zh\9zh.jpg
# ✅ Saved: alpha_cropped\15-sin\100sin.jpg
# ✅ Saved: alpha_cropped\15-sin\10sin.jpg
# ✅ Saved: alpha_cropped\15-sin\11sin.jpg
# ✅ Saved: alpha_cropped\15-sin\12sin.jpg
# ✅ Saved: alpha_cropped\15-sin\13sin.jpg
# ✅ Saved: alpha_cropped\15-sin\14sin.jpg
# ✅ Saved: alpha_cropped\15-sin\15sin.jpg
# ✅ Saved: alpha_cropped\15-sin\16sin.jpg
# ✅ Saved: alpha_cropped\15-sin\17sin.jpg
# ✅ Saved: alpha_cropped\15-sin\18sin.jpg
# ✅ Saved: alpha_cropped\15-sin\19sin.jpg
# ✅ Saved: alpha_cropped\15-sin\1sin.jpg
# ✅ Saved: alpha_cropped\15-sin\20sin.jpg
# ✅ Saved: alpha_cropped\15-sin\21sin.jpg
# ✅ Saved: alpha_cropped\15-sin\22sin.jpg
# ✅ Saved: alpha_cropped\15-sin\23sin.jpg
# ✅ Saved: alpha_cropped\15-sin\24sin.jpg
# ✅ Saved: alpha_cropped\15-sin\25sin.jpg
# ✅ Saved: alpha_cropped\15-sin\26sin.jpg
# ✅ Saved: alpha_cropped\15-sin\27sin.jpg
# ✅ Saved: alpha_cropped\15-sin\28sin.jpg
# ✅ Saved: alpha_cropped\15-sin\29sin.jpg
# ✅ Saved: alpha_cropped\15-sin\2sin.jpg
# ✅ Saved: alpha_cropped\15-sin\30sin.jpg
# ✅ Saved: alpha_cropped\15-sin\31sin.jpg
# ✅ Saved: alpha_cropped\15-sin\32sin.jpg
# ✅ Saved: alpha_cropped\15-sin\33sin.jpg
# ✅ Saved: alpha_cropped\15-sin\34sin.jpg
# ✅ Saved: alpha_cropped\15-sin\35sin.jpg
# ✅ Saved: alpha_cropped\15-sin\36sin.jpg
# ✅ Saved: alpha_cropped\15-sin\37sin.jpg
# ✅ Saved: alpha_cropped\15-sin\38sin.jpg
# ✅ Saved: alpha_cropped\15-sin\39sin.jpg
# ✅ Saved: alpha_cropped\15-sin\3sin.jpg
# ✅ Saved: alpha_cropped\15-sin\40sin.jpg
# ✅ Saved: alpha_cropped\15-sin\41sin.jpg
# ✅ Saved: alpha_cropped\15-sin\42sin.jpg
# ✅ Saved: alpha_cropped\15-sin\43sin.jpg
# ✅ Saved: alpha_cropped\15-sin\44sin.jpg
# ✅ Saved: alpha_cropped\15-sin\45sin.jpg
# ✅ Saved: alpha_cropped\15-sin\46sin.jpg
# ✅ Saved: alpha_cropped\15-sin\47sin.jpg
# ✅ Saved: alpha_cropped\15-sin\48sin.jpg
# ✅ Saved: alpha_cropped\15-sin\49sin.jpg
# ✅ Saved: alpha_cropped\15-sin\4sin.jpg
# ✅ Saved: alpha_cropped\15-sin\50sin.jpg
# ✅ Saved: alpha_cropped\15-sin\51sin.jpg
# ✅ Saved: alpha_cropped\15-sin\52sin.jpg
# ✅ Saved: alpha_cropped\15-sin\53sin.jpg
# ✅ Saved: alpha_cropped\15-sin\54sin.jpg
# ✅ Saved: alpha_cropped\15-sin\55sin.jpg
# ✅ Saved: alpha_cropped\15-sin\56sin.jpg
# ✅ Saved: alpha_cropped\15-sin\57sin.jpg
# ✅ Saved: alpha_cropped\15-sin\58sin.jpg
# ✅ Saved: alpha_cropped\15-sin\59sin.jpg
# ✅ Saved: alpha_cropped\15-sin\5sin.jpg
# ✅ Saved: alpha_cropped\15-sin\60sin.jpg
# ✅ Saved: alpha_cropped\15-sin\61sin.jpg
# ✅ Saved: alpha_cropped\15-sin\62sin.jpg
# ✅ Saved: alpha_cropped\15-sin\63sin.jpg
# ✅ Saved: alpha_cropped\15-sin\64sin.jpg
# ✅ Saved: alpha_cropped\15-sin\65sin.jpg
# ✅ Saved: alpha_cropped\15-sin\66sin.jpg
# ✅ Saved: alpha_cropped\15-sin\67sin.jpg
# ✅ Saved: alpha_cropped\15-sin\68sin.jpg
# ✅ Saved: alpha_cropped\15-sin\69sin.jpg
# ✅ Saved: alpha_cropped\15-sin\6sin.jpg
# ✅ Saved: alpha_cropped\15-sin\70sin.jpg
# ✅ Saved: alpha_cropped\15-sin\71sin.jpg
# ✅ Saved: alpha_cropped\15-sin\72sin.jpg
# ✅ Saved: alpha_cropped\15-sin\73sin.jpg
# ✅ Saved: alpha_cropped\15-sin\74sin.jpg
# ✅ Saved: alpha_cropped\15-sin\75sin.jpg
# ✅ Saved: alpha_cropped\15-sin\76sin.jpg
# ✅ Saved: alpha_cropped\15-sin\77sin.jpg
# ✅ Saved: alpha_cropped\15-sin\78sin.jpg
# ✅ Saved: alpha_cropped\15-sin\79sin.jpg
# ✅ Saved: alpha_cropped\15-sin\7sin.jpg
# ✅ Saved: alpha_cropped\15-sin\80sin.jpg
# ✅ Saved: alpha_cropped\15-sin\81sin.jpg
# ✅ Saved: alpha_cropped\15-sin\82sin.jpg
# ✅ Saved: alpha_cropped\15-sin\83sin.jpg
# ✅ Saved: alpha_cropped\15-sin\84sin.jpg
# ✅ Saved: alpha_cropped\15-sin\85sin.jpg
# ✅ Saved: alpha_cropped\15-sin\86sin.jpg
# ✅ Saved: alpha_cropped\15-sin\87sin.jpg
# ✅ Saved: alpha_cropped\15-sin\88sin.jpg
# ✅ Saved: alpha_cropped\15-sin\89sin.jpg
# ✅ Saved: alpha_cropped\15-sin\8sin.jpg
# ✅ Saved: alpha_cropped\15-sin\90sin.jpg
# ✅ Saved: alpha_cropped\15-sin\91sin.jpg
# ✅ Saved: alpha_cropped\2-b\40b.jpg
# ✅ Saved: alpha_cropped\2-b\41b.jpg
# ✅ Saved: alpha_cropped\2-b\42b.jpg
# ✅ Saved: alpha_cropped\2-b\43b.jpg
# ✅ Saved: alpha_cropped\2-b\44b.jpg
# ✅ Saved: alpha_cropped\2-b\45b.jpg
# ✅ Saved: alpha_cropped\2-b\46b.jpg
# ✅ Saved: alpha_cropped\2-b\47b.jpg
# ✅ Saved: alpha_cropped\2-b\48b.jpg
# ✅ Saved: alpha_cropped\2-b\49b.jpg
# ✅ Saved: alpha_cropped\2-b\4b.jpg
# ✅ Saved: alpha_cropped\2-b\50b.jpg
# ✅ Saved: alpha_cropped\2-b\51b.jpg
# ✅ Saved: alpha_cropped\2-b\52b.jpg
# ✅ Saved: alpha_cropped\2-b\53b.jpg
# ✅ Saved: alpha_cropped\2-b\54b.jpg
# ✅ Saved: alpha_cropped\2-b\55b.jpg
# ✅ Saved: alpha_cropped\2-b\56b.jpg
# ✅ Saved: alpha_cropped\2-b\57b.jpg
# ✅ Saved: alpha_cropped\2-b\58b.jpg
# ✅ Saved: alpha_cropped\2-b\59b.jpg
# ✅ Saved: alpha_cropped\2-b\5b.jpg
# ✅ Saved: alpha_cropped\2-b\60b.jpg
# ✅ Saved: alpha_cropped\2-b\61b.jpg
# ✅ Saved: alpha_cropped\2-b\62b.jpg
# ✅ Saved: alpha_cropped\2-b\63b.jpg
# ✅ Saved: alpha_cropped\2-b\64b.jpg
# ✅ Saved: alpha_cropped\2-b\65b.jpg
# ✅ Saved: alpha_cropped\2-b\66b.jpg
# ✅ Saved: alpha_cropped\2-b\67b.jpg
# ✅ Saved: alpha_cropped\2-b\68b.jpg
# ✅ Saved: alpha_cropped\2-b\69b.jpg
# ✅ Saved: alpha_cropped\2-b\6b.jpg
# ✅ Saved: alpha_cropped\2-b\70b.jpg
# ✅ Saved: alpha_cropped\2-b\71b.jpg
# ✅ Saved: alpha_cropped\2-b\72b.jpg
# ✅ Saved: alpha_cropped\2-b\73b.jpg
# ✅ Saved: alpha_cropped\2-b\74b.jpg
# ✅ Saved: alpha_cropped\2-b\75b.jpg
# ✅ Saved: alpha_cropped\2-b\76b.jpg
# ✅ Saved: alpha_cropped\2-b\77b.jpg
# ✅ Saved: alpha_cropped\2-b\78b.jpg
# ✅ Saved: alpha_cropped\2-b\79b.jpg
# ✅ Saved: alpha_cropped\2-b\7b.jpg
# ✅ Saved: alpha_cropped\2-b\80b.jpg
# ✅ Saved: alpha_cropped\2-b\81b.jpg
# ✅ Saved: alpha_cropped\2-b\82b.jpg
# ✅ Saved: alpha_cropped\2-b\83b.jpg
# ✅ Saved: alpha_cropped\2-b\84b.jpg
# ✅ Saved: alpha_cropped\2-b\85b.jpg
# ✅ Saved: alpha_cropped\2-b\86b.jpg
# ✅ Saved: alpha_cropped\2-b\87b.jpg
# ✅ Saved: alpha_cropped\2-b\88b.jpg
# ✅ Saved: alpha_cropped\2-b\89b.jpg
# ✅ Saved: alpha_cropped\2-b\8b.jpg
# ✅ Saved: alpha_cropped\8-h\17h.jpg
# ✅ Saved: alpha_cropped\8-h\18h.jpg
# ✅ Saved: alpha_cropped\8-h\19h.jpg
# ✅ Saved: alpha_cropped\8-h\1h.jpg
# ✅ Saved: alpha_cropped\8-h\20h.jpg
# ✅ Saved: alpha_cropped\8-h\21h.jpg
# ✅ Saved: alpha_cropped\8-h\22h.jpg
# ✅ Saved: alpha_cropped\8-h\23h.jpg
# ✅ Saved: alpha_cropped\8-h\24h.jpg
# ✅ Saved: alpha_cropped\8-h\25h.jpg
# ✅ Saved: alpha_cropped\8-h\26h.jpg
# ✅ Saved: alpha_cropped\8-h\27h.jpg
# ✅ Saved: alpha_cropped\8-h\28h.jpg
# ✅ Saved: alpha_cropped\8-h\29h.jpg
# ✅ Saved: alpha_cropped\8-h\2h.jpg
# ✅ Saved: alpha_cropped\8-h\30h.jpg
# ✅ Saved: alpha_cropped\8-h\31h.jpg
# ✅ Saved: alpha_cropped\8-h\32h.jpg
# ✅ Saved: alpha_cropped\8-h\33h.jpg
# ✅ Saved: alpha_cropped\8-h\34h.jpg
# ✅ Saved: alpha_cropped\8-h\35h.jpg
# ✅ Saved: alpha_cropped\8-h\36h.jpg
# ✅ Saved: alpha_cropped\8-h\37h.jpg
# ✅ Saved: alpha_cropped\8-h\38h.jpg
# ✅ Saved: alpha_cropped\8-h\39h.jpg
# ✅ Saved: alpha_cropped\8-h\3h.jpg
# ✅ Saved: alpha_cropped\8-h\40h.jpg
# ✅ Saved: alpha_cropped\8-h\41h.jpg
# ✅ Saved: alpha_cropped\8-h\42h.jpg
# ✅ Saved: alpha_cropped\8-h\43h.jpg
# ✅ Saved: alpha_cropped\8-h\44h.jpg
# ✅ Saved: alpha_cropped\8-h\45h.jpg
# ✅ Saved: alpha_cropped\8-h\46h.jpg
# ✅ Saved: alpha_cropped\8-h\47h.jpg
# ✅ Saved: alpha_cropped\8-h\48h.jpg
# ✅ Saved: alpha_cropped\8-h\49h.jpg
# ✅ Saved: alpha_cropped\8-h\4h.jpg
# ✅ Saved: alpha_cropped\8-h\50h.jpg
# ✅ Saved: alpha_cropped\8-h\51h.jpg
# ✅ Saved: alpha_cropped\8-h\52h.jpg
# ✅ Saved: alpha_cropped\8-h\53h.jpg
# ✅ Saved: alpha_cropped\8-h\54h.jpg
# ✅ Saved: alpha_cropped\8-h\55h.jpg
# ✅ Saved: alpha_cropped\8-h\56h.jpg
# ✅ Saved: alpha_cropped\8-h\57h.jpg
# ✅ Saved: alpha_cropped\8-h\58h.jpg
# ✅ Saved: alpha_cropped\8-h\59h.jpg
# ✅ Saved: alpha_cropped\8-h\5h.jpg
# ✅ Saved: alpha_cropped\8-h\60h.jpg
# ✅ Saved: alpha_cropped\8-h\61h.jpg
# ✅ Saved: alpha_cropped\8-h\62h.jpg
# ✅ Saved: alpha_cropped\8-h\63h.jpg
# ✅ Saved: alpha_cropped\8-h\64h.jpg
# ✅ Saved: alpha_cropped\8-h\65h.jpg
# ✅ Saved: alpha_cropped\8-h\66h.jpg
# ✅ Saved: alpha_cropped\9-kh\70kh.jpg
# ✅ Saved: alpha_cropped\9-kh\71kh.jpg
# ✅ Saved: alpha_cropped\9-kh\72kh.jpg
# ✅ Saved: alpha_cropped\9-kh\73kh.jpg
# ✅ Saved: alpha_cropped\9-kh\74kh.jpg
# ✅ Saved: alpha_cropped\9-kh\75kh.jpg
# ✅ Saved: alpha_cropped\9-kh\76kh.jpg
# ✅ Saved: alpha_cropped\9-kh\77kh.jpg
# ✅ Saved: alpha_cropped\9-kh\78kh.jpg
# ✅ Saved: alpha_cropped\9-kh\79kh.jpg
# ✅ Saved: alpha_cropped\9-kh\7kh.jpg
# ✅ Saved: alpha_cropped\9-kh\80kh.jpg
# ✅ Saved: alpha_cropped\9-kh\81kh.jpg
# ✅ Saved: alpha_cropped\9-kh\82kh.jpg
# ✅ Saved: alpha_cropped\9-kh\83kh.jpg
# ✅ Saved: alpha_cropped\9-kh\84kh.jpg
# ✅ Saved: alpha_cropped\9-kh\85kh.jpg
# ✅ Saved: alpha_cropped\9-kh\86kh.jpg
# ✅ Saved: alpha_cropped\9-kh\87kh.jpg
# ✅ Saved: alpha_cropped\9-kh\88kh.jpg
# ✅ Saved: alpha_cropped\9-kh\89kh.jpg
# ✅ Saved: alpha_cropped\9-kh\8kh.jpg
# ✅ Saved: alpha_cropped\9-kh\90kh.jpg
# ✅ Saved: alpha_cropped\9-kh\91kh.jpg
# ✅ Saved: alpha_cropped\9-kh\92kh.jpg
# ✅ Saved: alpha_cropped\9-kh\93kh.jpg
# ✅ Saved: alpha_cropped\9-kh\94kh.jpg
# ✅ Saved: alpha_cropped\9-kh\95kh.jpg
# ✅ Saved: alpha_cropped\9-kh\96kh.jpg
# ✅ Saved: alpha_cropped\9-kh\97kh.jpg
# ✅ Saved: alpha_cropped\9-kh\98kh.jpg
# ✅ Saved: alpha_cropped\9-kh\99kh.jpg
# ✅ Saved: alpha_cropped\9-kh\9kh.jpg

# %% [markdown]
# #### Train the models

# %%
def extract_hog_features(img_array):
    features = hog(img_array, orientations=9, pixels_per_cell=(4, 4), cells_per_block=(2, 2), block_norm='L2-Hys')
    return features

def elastic_transform(image, alpha=34, sigma=4):
    image = np.array(image)
    random_state = np.random.RandomState(None)

    shape = image.shape
    dx = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma) * alpha
    dy = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma) * alpha

    x, y = np.meshgrid(np.arange(shape[1]), np.arange(shape[0]))
    indices = np.reshape(y + dy, (-1, 1)), np.reshape(x + dx, (-1, 1))

    distorted = map_coordinates(image, indices, order=1, mode='reflect').reshape(shape)
    return Image.fromarray(distorted.astype(np.uint8))

def add_noise(img):
    noisy = np.array(img).astype(np.float32)
    noise = np.random.normal(0, 10, noisy.shape)
    noisy = np.clip(noisy + noise, 0, 255).astype(np.uint8)
    return Image.fromarray(noisy)


def random_affine(img):
    angle = random.uniform(-10, 10)
    translate = (random.uniform(-2, 2), random.uniform(-2, 2))
    scale = random.uniform(0.9, 1.1)

    return img.rotate(angle, resample=Image.BICUBIC, fillcolor=255).transform(
        img.size, Image.AFFINE,
        (scale, 0, translate[0], 0, scale, translate[1]),
        resample=Image.BICUBIC,
        fillcolor=255
    )

def augment_image(img):
    augmented_images = []

    if not isinstance(img, Image.Image):
        img = Image.fromarray(img)

    augmented_images.append(random_affine(img))
    augmented_images.append(add_noise(img))
    augmented_images.append(elastic_transform(img))

    return augmented_images


image_size = (28, 28)
dataset_path = "alpha_cropped" 

X, y = [], []
labels = {}

for idx, label_folder in enumerate(sorted(os.listdir(dataset_path))):
    folder_path = os.path.join(dataset_path, label_folder)
    if os.path.isdir(folder_path):
        labels[idx] = label_folder
        for img_file in os.listdir(folder_path):
            img_path = os.path.join(folder_path, img_file)
            try:
                img = Image.open(img_path).convert("L").resize(image_size)
                img_array = np.array(img)
                
                # Original image features
                hog_features = extract_hog_features(img_array)
                X.append(hog_features)
                y.append(idx)

                # Augmented images (same label)
                for aug_img in augment_image(img):
                    aug_array = np.array(aug_img)
                    hog_aug = extract_hog_features(aug_array)
                    X.append(hog_aug)
                    y.append(idx)

            except Exception as e:
                print(f"خطا در پردازش {img_path}: {e}")

# نرمال‌سازی
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# کاهش ابعاد با PCA
pca = PCA(n_components=50)
X_pca = pca.fit_transform(X_scaled)

# تقسیم داده‌ها به آموزش و تست
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.1, random_state=42)

# مدل SVM
svm_model = SVC(kernel='linear')
svm_scores = cross_val_score(svm_model, X_train, y_train, cv=5)
print(f"SVM دقت: {np.mean(svm_scores):.2f} ± {np.std(svm_scores):.2f}")

# مدل درخت تصمیم
tree_model = DecisionTreeClassifier()
tree_scores = cross_val_score(tree_model, X_train, y_train, cv=5)

svm_model.fit(X_train, y_train)
tree_model.fit(X_train, y_train)

print(f"درخت تصمیم دقت: {np.mean(tree_scores):.2f} ± {np.std(tree_scores):.2f}")
# Out:
# SVM دقت: 0.89 ± 0.01
# درخت تصمیم دقت: 0.68 ± 0.00

# %% [markdown]
# # Phase 4: Test

# %%
image_size = (28, 28)

base_output_folder = "output"
base_path = os.path.join(base_output_folder, "Extracted_characters_thresh")

predict_dir = "predicted"
os.makedirs(predict_dir, exist_ok=True)

output_dir = os.path.join(predict_dir, "1")
os.makedirs(output_dir, exist_ok=True)


svm_plate_predictions = defaultdict(list)
tree_plate_predictions = defaultdict(list)
def predict_image_batch(img_path, file_name):
    try:
        img = Image.open(img_path).convert("L").resize(image_size)
        img_array = np.array(img)
        hog_features = extract_hog_features(img_array)
        img_scaled = scaler.transform([hog_features])
        img_pca = pca.transform(img_scaled)

        svm_pred = svm_model.predict(img_pca)[0]
        tree_pred = tree_model.predict(img_pca)[0]

        svm_label = labels[svm_pred].split("-")[1]
        tree_label = labels[tree_pred].split("-")[1]

        # استخراج شماره پلاک
        plate_id = file_name.split("_")[0]

        svm_plate_predictions[plate_id].append(svm_label)
        tree_plate_predictions[plate_id].append(tree_label)

        # save images
        save_filename = f"{file_name}_SVM-{svm_label}_DT-{tree_label}.png"
        save_path = os.path.join(output_dir, save_filename)
        cv2.imwrite(save_path, img_array)

        # print(f"✅ Saved: {save_filename}")
    except Exception as e:
        print(f"❌ Error processing {img_path}: {e}")

# Predict on all images in base_path
for index, img_file in enumerate(sorted(os.listdir(base_path))):
    img_path = os.path.join(base_path, img_file)
    if os.path.isfile(img_path):
        file_name = img_file.split(".")[0]
        predict_image_batch(img_path, file_name)
        
        
        
def save_predictions_to_txt(predictions_dict, output_file):
    with open(output_file, "w", encoding="utf-8") as f:
        f.write("name,plate\n")
        for plate_id in sorted(predictions_dict.keys(), key=lambda x: int(x)):
            preds = predictions_dict[plate_id]
            line = f"{plate_id}," + ",".join(preds)
            f.write(line + "\n")

save_predictions_to_txt(svm_plate_predictions, "svm_predictions.txt")
save_predictions_to_txt(tree_plate_predictions, "tree_predictions.txt")

# %% [markdown]
# # Phase 5: Evaluation

# %%
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score
import matplotlib.pyplot as plt

# %%
true_plates = {}
with open("./Plates2/plate_labels.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()[1:]  # رد کردن هدر
    for line in lines:
        parts = line.strip().split(",")
        true_plates[parts[0]] = parts[1:]
        
def evaluate_model(true_plates, predicted_plates, model_name, output_txt_file):
    all_true = []
    all_pred = []
    exact_match_count = 0
    common_ids = set(true_plates.keys()) & set(predicted_plates.keys())

    for plate_id in sorted(common_ids, key=lambda x: int(x)):
        true = true_plates[plate_id]
        pred = predicted_plates[plate_id]

        # فقط اگر طول‌شون برابر باشه لحاظ بشه
        if len(true) != len(pred):
            continue

        if true == pred:
            exact_match_count += 1

        all_true.extend(true)
        all_pred.extend(pred)

    total_plates = len(common_ids)
    plate_accuracy = exact_match_count / total_plates if total_plates else 0
    acc = accuracy_score(all_true, all_pred)
    prec = precision_score(all_true, all_pred, average='macro', zero_division=0)
    rec = recall_score(all_true, all_pred, average='macro', zero_division=0)
    cm = confusion_matrix(all_true, all_pred, labels=np.unique(all_true + all_pred))
    labels_sorted = list(np.unique(all_true + all_pred))

    with open(output_txt_file, "w", encoding="utf-8") as f:
        f.write(f"🔹 {model_name} Evaluation\n")
        f.write(f"✔️ دقت کامل پلاک‌ها: {plate_accuracy:.2f}\n")
        f.write(f"✔️ Accuracy (کاراکتر): {acc:.2f}\n")
        f.write(f"✔️ Precision (macro): {prec:.2f}\n")
        f.write(f"✔️ Recall (macro): {rec:.2f}\n\n")
        f.write("📊 Confusion Matrix:\n")
        f.write("True\\Pred" + "\t" + "\t".join(labels_sorted) + "\n")
        for i, row in enumerate(cm):
            f.write(labels_sorted[i] + "\t" + "\t".join(str(x) for x in row) + "\n")

    # ذخیره تصویر گرافیکی
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=labels_sorted, yticklabels=labels_sorted, cmap="Blues")
    plt.title(f"Confusion Matrix - {model_name}")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.tight_layout()
    plt.savefig(f"{model_name}_confusion_matrix.png")
    plt.show()

# اجرا برای هر مدل
evaluate_model(true_plates, svm_plate_predictions, "SVM", "svm_evaluation.txt")
evaluate_model(true_plates, tree_plate_predictions, "DecisionTree", "tree_evaluation.txt")
